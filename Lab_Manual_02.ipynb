# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Lab 3 Topic

# %% [markdown]
# pandas, matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,3,5,9,10]
plt.plot(x,y)

# %%
import pandas as pd

# %% [markdown]
# # What is DataFrame?

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],
      "score":[90,80,85,75,95,60,65],
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],
      "gender":["M","M","M","M","F","F","F"]}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    name  score      sport gender
# 0  Bill     90  Wrestling      M
# 1   Tom     80   Football      M
# 2   Tim     85     Skiing      M
# 3  John     75   Swimming      M
# 4  Alex     95     Tennis      F

# %%
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-86eeda312824> in <cell line: 1>()
# ----> 1 print(df.shape)
#
# NameError: name 'df' is not defined

# %%
df.tail()
# Out:
#       name  score     sport gender
# 2      Tim     85    Skiing      M
# 3     John     75  Swimming      M
# 4     Alex     95    Tennis      F
# 5  Vanessa     60    Karete      F
# 6     Kate     65   Surfing      F

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"])
df
# Out:
#       name      sport gender  score  age
# 0     Bill  Wrestling      M     90  NaN
# 1      Tom   Football      M     80  NaN
# 2      Tim     Skiing      M     85  NaN
# 3     John   Swimming      M     75  NaN
# 4     Alex     Tennis      F     95  NaN
# 5  Vanessa     Karete      F     60  NaN
# 6     Kate    Surfing      F     65  NaN

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"],
                index=["one","two","three","four","five","six","seven"])
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90  NaN
# two        Tom   Football      M     80  NaN
# three      Tim     Skiing      M     85  NaN
# four      John   Swimming      M     75  NaN
# five      Alex     Tennis      F     95  NaN
# six    Vanessa     Karete      F     60  NaN
# seven     Kate    Surfing      F     65  NaN

# %%
df["sport"]
# Out:
# one      Wrestling
# two       Football
# three       Skiing
# four      Swimming
# five        Tennis
# six         Karete
# seven      Surfing
# Name: sport, dtype: object

# %%
df.loc[["one"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling      M     90  NaN

# %%
df.loc[["one","two"]]
# Out:
#      name      sport gender  score  age
# one  Bill  Wrestling      M     90  NaN
# two   Tom   Football      M     80  NaN

# %%
df=pd.DataFrame(data,columns=["name", "sport", "gender", "score", "age"],
                index=["one","two","three","four","five","six","seven"])
values=[18,19,20,18,17,17,18]
df["age"]=values
df
# Out:
#           name      sport gender  score  age
# one       Bill  Wrestling      M     90   18
# two        Tom   Football      M     80   19
# three      Tim     Skiing      M     85   20
# four      John   Swimming      M     75   18
# five      Alex     Tennis      F     95   17
# six    Vanessa     Karete      F     60   17
# seven     Kate    Surfing      F     65   18

# %%
df["pass"]=df.score>=70
df
# Out:
#           name      sport gender  score  age   pass
# one       Bill  Wrestling      M     90   18   True
# two        Tom   Football      M     80   19   True
# three      Tim     Skiing      M     85   20   True
# four      John   Swimming      M     75   18   True
# five      Alex     Tennis      F     95   17   True
# six    Vanessa     Karete      F     60   17  False
# seven     Kate    Surfing      F     65   18  False

# %% [markdown]
# # Series Data Structure

# %%
obj=pd.Series([1,"John",3.5,"Hey"])
obj
# Out:
# 0       1
# 1    John
# 2     3.5
# 3     Hey
# dtype: object

# %%
obj.values
# Out:
# array([1, 'John', 3.5, 'Hey'], dtype=object)

# %%
obj2=pd.Series([1,"John",3.5,"Hey"],index=["a","b","c","d"])
obj2
# Out:
# a       1
# b    John
# c     3.5
# d     Hey
# dtype: object

# %%
obj2["b"]
# Out:
# 'John'

# %% [markdown]
# # Working with Series Data Structure

# %%
pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=d72266a77b633780b30d2226a91f171db7f99e9ab30fc33175dd5a321fc7ec09
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import wget
# !wget https://raw.githubusercontent.com/TirendazAcademy/PANDAS-TUTORIAL/main/DataSets/vgsalesGlobale.csv
# Out:
# --2023-09-03 07:53:28--  https://raw.githubusercontent.com/TirendazAcademy/PANDAS-TUTORIAL/main/DataSets/vgsalesGlobale.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1355781 (1.3M) [text/plain]
# Saving to: ‘vgsalesGlobale.csv’
#
# vgsalesGlobale.csv  100%[===================>]   1.29M  --.-KB/s    in 0.06s
#
# 2023-09-03 07:53:29 (23.2 MB/s) - ‘vgsalesGlobale.csv’ saved [1355781/1355781]

# %%
games=pd.read_csv("/content/vgsalesGlobale.csv", sep=',')

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.Genre.describe()
# Out:
# count      16598
# unique        12
# top       Action
# freq        3316
# Name: Genre, dtype: object

# %%
games.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
games.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
games.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
pd.crosstab(games.Genre, games.Year)
# Out:
# Year          1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  1986.0  1987.0  \
# Genre
# Action             1      25      18       7       1       2       6       2
# Adventure          0       0       0       1       0       0       0       1
# Fighting           1       0       0       0       0       1       0       2
# Misc               4       0       1       1       1       0       0       0
# Platform           0       3       5       5       1       4       6       2
# Puzzle             0       2       3       1       3       4       0       0
# Racing             0       1       2       0       3       0       1       0
# Role-Playing       0       0       0       0       0       0       1       3
# Shooter            2      10       5       1       3       1       4       2
# Simulation         0       1       0       0       0       1       0       0
# Sports             1       4       2       1       2       1       3       4
# Strategy           0       0       0       0       0       0       0       0
#
# Year          1988.0  1989.0  ...  2009.0  2010.0  2011.0  2012.0  2013.0  \
# Genre                         ...
# Action             2       2  ...     272     226     239     266     148
# Adventure          0       0  ...     141     154     108      58      60
# Fighting           0       0  ...      53      40      50      29      20
# Misc               0       1  ...     207     201     184      38      42
# Platform           4       3  ...      29      31      37      12      37
# Puzzle             1       5  ...      79      45      43      11       3
# Racing             1       0  ...      84      57      65      30      16
# Role-Playing       3       2  ...     103     103      95      78      71
# Shooter            1       1  ...      91      81      94      48      59
# Simulation         1       0  ...     123      82      56      18      18
# Sports             2       3  ...     184     186     122      54      53
# Strategy           0       0  ...      65      53      46      15      19
#
# Year          2014.0  2015.0  2016.0  2017.0  2020.0
# Genre
# Action           186     255     119       1       0
# Adventure         75      54      34       0       0
# Fighting          23      21      14       0       0
# Misc              41      39      18       0       0
# Platform          10      14      10       0       0
# Puzzle             8       6       0       0       0
# Racing            27      19      20       0       0
# Role-Playing      91      78      40       2       0
# Shooter           47      34      32       0       0
# Simulation        11      15       9       0       1
# Sports            55      62      38       0       0
# Strategy           8      17      10       0       0
#
# [12 rows x 39 columns]

# %%
games.Global_Sales.mean()
# Out:
# 0.5374406555006628

# %% [markdown]
# Summarizing & Computing Descriptive Statistics

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame([[2.4,np.nan],[6.3,-5.4],[np.nan,np.nan],[0.75,-1.3]],
                index=["a","b","c","d"],
                columns=["one","two"])
df
# Out:
#     one  two
# a  2.40  NaN
# b  6.30 -5.4
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.sum()
# Out:
# one    9.45
# two   -6.70
# dtype: float64

# %%
df.sum(axis=1)
# Out:
# a    2.40
# b    0.90
# c    0.00
# d   -0.55
# dtype: float64

# %%
df.idxmax()
# Out:
# one    b
# two    d
# dtype: object

# %% [markdown]
# # Indexing & Selection & Filtering in Pandas

# %%
obj=pd.Series(np.arange(5),
              index=["a","b","c","d","e"])

obj
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
obj["c"]
# Out:
# 2

# %%
print(obj[["a","c"]])
print(obj[[0,2]])
# Out:
# a    0
# c    2
# dtype: int64
# a    0
# c    2
# dtype: int64

# %% [markdown]
# # DataFrame Indexing

# %%
data=pd.DataFrame(
    np.arange(16).reshape(4,4),
    index=["London","Paris",
           "Berlin","Istanbul"],
    columns=["one","two","three","four"])
data
# Out:
#           one  two  three  four
# London      0    1      2     3
# Paris       4    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %%
data[["one","two"]]
# Out:
#           one  two
# London      0    1
# Paris       4    5
# Berlin      8    9
# Istanbul   12   13

# %%
data[:3]
# Out:
#         one  two  three  four
# London    0    1      2     3
# Paris     4    5      6     7
# Berlin    8    9     10    11

# %%
data[data["four"]>5]
# Out:
#           one  two  three  four
# Paris       4    5      6     7
# Berlin      8    9     10    11
# Istanbul   12   13     14    15

# %% [markdown]
# # Selecting with iloc and loc

# %%
data.iloc[1]
# Out:
# one      4
# two      5
# three    6
# four     7
# Name: Paris, dtype: int64

# %%
data.iloc[1,[1,2,3]]
# Out:
# two      5
# three    6
# four     7
# Name: Paris, dtype: int64

# %%
data.iloc[[1,3],[1,2,3]]
# Out:
#           two  three  four
# Paris       5      6     7
# Istanbul   13     14    15

# %%
data.loc["Paris",["one","two"]]
# Out:
# one    4
# two    5
# Name: Paris, dtype: int64

# %%
from PIL import Image

image = Image.open('/content/drive/MyDrive/datasetimage/ai.jpeg')

if image is not None:
    pixel_data = list(image.getdata())

    width = image.width

    first_row = pixel_data[:width]
    image.show()
    print("First row values:", first_row)

else:
    print("Image not found or could not be opened.")
# Out:
# First row values: [(0, 30, 55), (0, 27, 51), (0, 20, 44), (23, 48, 70), (75, 93, 115), (75, 90, 109), (56, 64, 83), (63, 69, 85), (77, 79, 94), (75, 75, 87), (73, 70, 81), (73, 70, 79), (78, 73, 80), (81, 76, 83), (82, 77, 84), (82, 77, 84), (86, 81, 88), (85, 80, 87), (84, 78, 88), (83, 77, 87), (82, 76, 88), (80, 74, 86), (77, 73, 88), (77, 73, 88), (70, 67, 86), (74, 71, 90), (76, 74, 96), (74, 72, 94), (70, 67, 94), (68, 65, 92), (71, 68, 97), (77, 71, 99), (56, 43, 69), (71, 57, 82), (63, 53, 77), (67, 59, 82), (77, 72, 92), (62, 54, 75), (78, 69, 88), (145, 132, 150), (93, 72, 91), (89, 66, 82), (145, 125, 137), (171, 156, 163), (156, 147, 150), (146, 147, 142), (130, 140, 132), (141, 147, 145), (158, 145, 165), (166, 152, 178), (162, 156, 182), (0, 5, 27), (0, 15, 34), (2, 35, 50), (0, 33, 47), (0, 33, 45), (0, 31, 45), (0, 30, 45), (0, 26, 48), (0, 23, 48), (5, 19, 48), (12, 15, 48), (19, 11, 50), (17, 13, 50), (8, 19, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51), (2, 21, 51),